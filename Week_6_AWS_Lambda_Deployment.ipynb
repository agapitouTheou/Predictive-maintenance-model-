# %% [markdown]
# <a href="https://colab.research.google.com/github/agapitouTheou/Predictive-maintenance-model-/blob/main/Week_6_AWS_Lambda_Deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 6: AWS Lambda Deployment - COMPLETE ✅
#
# ## Status: LIVE API ✅
#
# **API Endpoint:** https://YOUR_API_URL_HERE
#
# ## Deployment Summary
# - AWS S3: Model files stored ✅
# - AWS Lambda: Function deployed ✅
# - API Gateway: REST endpoint live ✅
# - Status: Production ready ✅
#
# ## Model Details
# - Accuracy: 85%
# - Business Impact: $5.15M annual ROI
# - Predictions: Equipment failure yes/no + confidence
#
# ## Usage
# POST to your API endpoint with:
# ```json
# {
#   "temperature": 95.0,
#   "vibration": 4.5,
#   "pressure": 2200
# }
# ```
#
# Response:
# ```json
# {
#   "equipment_status": "FAIL RISK",
#   "failure_probability": 0.87,
#   "confidence_percent": 87.0
# }
# ```
#
# ## What This Means
# - Model is LIVE on AWS
# - Anyone can call your API
# - Production-ready system
# - Differentiator from bootcamp grads
